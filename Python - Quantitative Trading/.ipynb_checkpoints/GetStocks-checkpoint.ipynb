# %% [markdown]
# ## Import libaray

# %%
import requests
from io import StringIO
import pandas as pd
import numpy as np

# %% [markdown]
# ## Download data from Taiwan Stock Exchange Corporation

# %%
SearchDate = '20181207'
DataFromWeb = requests.get('http://www.twse.com.tw/exchangeReport/MI_INDEX?response=csv&date=' + SearchDate + '&type=ALLBUT0999')
DataFromWeb.text[:100]
# Out:
# '"107年12月07日 大盤統計資訊"\r\n"指數","收盤指數","漲跌(+/-)","漲跌點數","漲跌百分比(%)",\r\n"寶島股價指數","11,167.75","+","92.50","0.8'

# %% [markdown]
# ## Parse the data by Pandas

# %%
temp_list = []

for temp in DataFromWeb.text.split('\n'):
    if len(temp.split('",')) == 17 and temp[0] != '=':
        temp_list.append(temp)

target_dict = {ord(c): None for c in ' '}

String_Data = StringIO("\n".join([i.translate(target_dict) for i in temp_list]))

df = pd.read_csv(String_Data)

df[:5]
# Out:
#    證券代號 證券名稱       成交股數   成交筆數         成交金額    開盤價    最高價    最低價    收盤價  \
# 0  1101   台泥  9,683,367  3,804  339,627,959  34.70  35.45  34.70  35.05
# 1  1102   亞泥  3,244,244  1,511  108,320,638  33.30  33.55  33.05  33.50
# 2  1103   嘉泥    717,139    266    9,936,920  13.85  13.95  13.75  13.90
# 3  1104   環泥     52,627     54    1,009,455  19.15  19.25  19.10  19.20
# 4  1108   幸福     32,682     16      235,750   7.20   7.22   7.20   7.22
#
#   漲跌(+/-)  漲跌價差 最後揭示買價 最後揭示買量 最後揭示賣價 最後揭示賣量    本益比  Unnamed: 16
# 0       +  0.40  35.05    307  35.10     16   9.63          NaN
# 1       +  0.35  33.45     11  33.50     55  10.24          NaN
# 2       +  0.10  13.90     32  13.95     67   4.91          NaN
# 3       +  0.10  19.15     16  19.25     25  10.97          NaN
# 4       +  0.05   7.22     41   7.23     15   0.00          NaN

# %% [markdown]
# ## Select Stocks

# %%
# 用本益比<15的條件來篩選
df1 = df[pd.to_numeric(df['本益比'], errors='coerce') < 15]
df1[:10]
# Out:
#     證券代號 證券名稱       成交股數   成交筆數         成交金額    開盤價    最高價    最低價    收盤價  \
# 0   1101   台泥  9,683,367  3,804  339,627,959  34.70  35.45  34.70  35.05
# 1   1102   亞泥  3,244,244  1,511  108,320,638  33.30  33.55  33.05  33.50
# 2   1103   嘉泥    717,139    266    9,936,920  13.85  13.95  13.75  13.90
# 3   1104   環泥     52,627     54    1,009,455  19.15  19.25  19.10  19.20
# 4   1108   幸福     32,682     16      235,750   7.20   7.22   7.20   7.22
# 5   1109   信大     51,500     24      759,050  14.70  14.80  14.55  14.80
# 7   1201   味全    486,301    262   10,819,496  22.30  22.45  22.05  22.25
# 8   1203   味王     27,362     32      698,314  25.50  25.75  25.40  25.75
# 9   1210   大成    426,399    321   13,714,089  32.10  32.30  32.10  32.15
# 10  1213   大飲     16,193     17      176,392  10.85  10.95  10.85  10.85
#
#    漲跌(+/-)  漲跌價差 最後揭示買價 最後揭示買量 最後揭示賣價 最後揭示賣量    本益比  Unnamed: 16
# 0        +  0.40  35.05    307  35.10     16   9.63          NaN
# 1        +  0.35  33.45     11  33.50     55  10.24          NaN
# 2        +  0.10  13.90     32  13.95     67   4.91          NaN
# 3        +  0.10  19.15     16  19.25     25  10.97          NaN
# 4        +  0.05   7.22     41   7.23     15   0.00          NaN
# 5        +  0.30  14.70      1  14.80      9   6.98          NaN
# 7      NaN  0.00  22.25      9  22.30     44   7.04          NaN
# 8        +  0.20  25.50      1  25.75     13  14.23          NaN
# 9      NaN  0.00  32.10     34  32.15     13  10.40          NaN
# 10       +  0.15  10.85     12  10.95     11   0.00          NaN

# %% [markdown]
# ## Resort the Stocks

# %%
df2 = df[pd.to_numeric(df['本益比'], errors='coerce') < 15].sort_values(by=['本益比', '收盤價'], ascending = False)
df2[:10]
# Out:
#      證券代號   證券名稱       成交股數   成交筆數         成交金額    開盤價    最高價    最低價    收盤價  \
# 135  1583     程泰      4,000      4      199,150  49.95  50.00  49.60  49.60
# 941  9943    好樂迪     32,351     34    1,876,733  57.90  58.20  57.80  58.20
# 771  6189     豐藝    128,475     61    3,665,504  28.40  28.60  28.40  28.60
# 533  3028    增你強    188,275    113    4,005,517  21.15  21.35  21.15  21.35
# 740  5871  中租-KY  1,867,489  1,025  180,964,421  96.00  97.40  95.60  97.30
# 938  9941     裕融    169,756    160   15,037,555  87.90  89.00  87.90  88.70
# 12   1216     統一  8,672,121  4,500  594,440,537  68.20  68.90  68.00  68.90
# 462  2823     中壽  5,444,115  2,105  159,540,999  29.50  29.55  29.15  29.30
# 115  1525     江申     37,000     29    2,040,600  55.30  56.40  54.80  56.40
# 916  9911     櫻花    158,824    124    5,604,853  35.65  35.70  35.15  35.20
#
#     漲跌(+/-)  漲跌價差 最後揭示買價 最後揭示買量 最後揭示賣價 最後揭示賣量   本益比  Unnamed: 16
# 135       +  0.30  49.60      1  50.30      2  9.94          NaN
# 941       +  0.30  58.10      1  58.30      7  9.93          NaN
# 771       +  0.10  28.50     55  28.60     37  9.93          NaN
# 533       +  0.20  21.30      5  21.35     29  9.93          NaN
# 740       +  2.00  97.20      1  97.30     25  9.91          NaN
# 938       +  1.20  88.60     30  89.00      2  9.87          NaN
# 12        +  1.50  68.80    320  68.90      5  9.84          NaN
# 462       -  0.10  29.30    346  29.35     10  9.83          NaN
# 115       +  1.70  56.30      1  56.50      1  9.81          NaN
# 916       -  0.45  35.20     17  35.25     20  9.78          NaN
