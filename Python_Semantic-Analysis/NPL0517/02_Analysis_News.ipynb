# %% [markdown]
# ## Download News From Website

# %%
# import function to get news contents
# %run GetNewsFun.ipynb

# %%
SearchString = '離岸風電'
StartDate = '20190301'
EndDate = '20190430'

# %%
appleNews(SearchString, StartDate, EndDate, rep=None)
# Out:
# 20190430_【巨頭交鋒2】韓國瑜：感覺像總統大選辯論　讓我有點錯亂
# 20190430_網友留言「殺韓幹韓市長女兒」　高市府已報案
# 20190430_有為韓國瑜收4千萬一事道歉？　蔡正元：亂講
# 20190430_【巨頭交鋒10】​郭台銘自曝2周後與韓國瑜見面　打造HPC生產基地
# 20190430_【現場觀察】韓、郭、朱比人氣拚論述　經濟論壇儼然成總統初選辯論會
# 20190430_【巨頭交鋒9】郭台銘嗆馬雲：「台灣創業家並不都是LKK！」
# 20190430_韓國瑜談台灣未來　16字箴言要「征服宇宙」
# 20190430_辣台派與韓粉，絕非民主的真諦
# 20190430_【新聞分析】韓國瑜被動參選　黨內人士：「落跑市長」將會是關鍵
# 20190430_【吳韓會1】韓國瑜被動參選2020　國民黨：特別辦法最快5月8日送出
# 20190430_韓國瑜挺佳芬秘書人事案　「給力爭上游年輕人機會」
# 20190430_吳韓會後表態選總統？　韓國瑜：下午就知
# 20190430_【巨頭交鋒8】葛永光：韓國瑜、郭台銘同打經濟牌　差別在庶民與高科技
# 20190430_【吳韓會6】學者曲兆祥：國民黨若馬上民調　韓國瑜較占上風
# 20190430_【巨頭交鋒5】朱立倫點名郭台銘：別拼富民經濟而是全民經濟
# 20190430_韓國瑜參選最大變數　邱毅認為是天氣
# 20190430_跟著韓國瑜雙語政策走　高市警局英語歌舞微電影上映
# 20190430_【民調結束】韓國瑜「被動參加初選」　國民黨大選「三巨頭」郭台銘獲4成支持勝韓國瑜
# 20190430_勞團抗議中央重北輕南　喊話韓國瑜降價旗津渡海費
# 20190430_韓國瑜四聲明不參加黨內民調　綠營議員批「仍在等黃袍加身」
# 20190430_【巨頭交鋒4】誰是台灣投資教父　郭台銘：郭媽媽是第一
# 20190430_​【郭董誤會了】中國人當然不打中國人，他們打的是台灣人
# 20190430_【巨頭交鋒3】投資界評郭韓表現　「國家劇院對上歌仔戲」
# 20190430_​談城市行銷　韓國瑜夫婦明至世新演講
# 20190430_老公捐款稱「韓國瑜很苦」　收入1.29億！廣告小妹：菜錢還我
# 20190430_【吳韓會5】見完吳敦義後消失30分鐘　韓國瑜做了這件事
# 20190430_【吳韓會4】國民黨：已確認韓國瑜意願　將採「全民調」協調式初選
# 20190430_去年募4千多萬打選戰　柯Ｐ：募太多、蟑螂老鼠都跑出來
# 20190430_「志玲非我不可予以尊重」　律師諷韓國瑜不主動外遇
# 20190430_韓國瑜5點變4點差在哪？　閉門會後不譙密室協商了
# 20190430_豪宅買氣回溫　「扁家最愛建商」蓋190億豪宅
# 20190430_【吳韓會3】朱立倫：國民黨推最強人選　一手好牌勝民進黨爛牌
# 20190430_【巨頭交鋒1】為自己拉票　郭台銘：盼給經營企業45年的人一個機會
# 20190430_【被動參選】韓國瑜宣布不參加總統初選　但黨部安排予以尊重
# 20190430_看不懂韓國瑜選不選？　名嘴超白話翻譯
# 20190430_【吳韓會2】才剛批權貴密室　韓國瑜今與吳敦義閉門過招（動畫）
# 20190430_【圓桌論壇1】郭董高喊台美中三贏　鐵口直斷沒有G20只有G2
# 20190430_【全文】馬英九批「反中」拖垮台灣經濟　籲民進黨設「自經區」
# 20190430_滷肉飯選舉花1.14億元　韓國瑜：多用在文宣
# 20190430_【對話曝光】王浩宇狂傳LINE要韓謝恩　被潘恒旭封鎖
# 20190430_「中國人不打中國人」？館長回嗆「難道你沒有尊嚴嗎」
# 20190430_新時代法律學社：選舉經費「上限」怎麼了？
# 20190430_馬英九批「新南向政策」成效差　只增加非法打工與賣春人口
# 20190430_批韓國瑜「用過即丟」　苦苓嘆黃光芹：識人不明
# 20190430_只補助韓國瑜12萬選市長　吳敦義：因為國民黨被清算
# 20190430_替陳學聖「寫個慘字」　選桃園市長！國民黨一毛都沒給
# 20190430_為韓國瑜槓上馬系羅智強　帶你看蔡正元與馬英九恩怨史
# 20190430_辣蘋果：韓國瑜自找危機（余艾苔）
# 20190430_好貴的滷肉飯 韓國瑜選市長花1.1億 六都第二
# 20190430_募款王 韓國瑜吸1.2億 選高市長帳目曝光 韓粉小額捐高達2.2萬筆
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Anaconda3\envs\envNews\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-37fb0a48bb5e> in <module>
# ----> 1 appleNews(SearchString, StartDate, EndDate, rep=None)
#
# <ipython-input-6-163f05a94a7c> in appleNews(SearchString, StartDate_Str, EndDate_Str, rep)
#      29             article_title = content['title']
#      30             article_publish_date = content['pubDate']
# ---> 31             article_data = requests.get(content['sharing']['url']).text
#      32
#      33             article_data_suop = BeautifulSoup(article_data, 'html.parser')
#
# d:\Anaconda3\envs\envNews\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# d:\Anaconda3\envs\envNews\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# d:\Anaconda3\envs\envNews\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# d:\Anaconda3\envs\envNews\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# d:\Anaconda3\envs\envNews\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# d:\Anaconda3\envs\envNews\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# d:\Anaconda3\envs\envNews\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# d:\Anaconda3\envs\envNews\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# d:\Anaconda3\envs\envNews\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# d:\Anaconda3\envs\envNews\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# d:\Anaconda3\envs\envNews\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# d:\Anaconda3\envs\envNews\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# d:\Anaconda3\envs\envNews\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
model = tf.keras.models.load_model('my_model.h5')

# %%
import re
from zhconv import convert
import jieba


stopWords=[]

# 讀入停用詞檔
with open('stopWords.txt', 'r', encoding='UTF-8') as file:
    for data in file.readlines():
        data = data.strip()
        stopWords.append(data)

news_folder_name = SearchString

filename_list = os.listdir(news_folder_name)

for filename in filename_list:
    with open(news_folder_name + '/'+ filename, encoding='UTF-8', errors='ignore') as f:
        news_text = f.read()
        date, title,_ = re.split(r"[_.]", filename)
        print (date, title)
        f.close()

#     news_text_cn = convert(news_text, 'zh-cn')
    news_text_cn = convert(title, 'zh-cn')
    
    # #剔除所有符號
    symbol_regex = '[’!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]+）（'

    # #剔除所有數字
    decimal_regex = re.compile(r"[^a-zA-Z]\d+")

    # #剔除空格
    space_regex = re.compile(r"\s+")

    comment_text = news_text_cn.strip()

    comment_text = re.sub(symbol_regex, '', comment_text)
    comment_text = decimal_regex.sub(r"", comment_text)
    comment_text = space_regex.sub(r"", comment_text)

    comment_text_cut = jieba.cut(comment_text,cut_all=False)

    remainderWords = list(filter(lambda a: a not in stopWords and a != '\n', comment_text_cut))

    token_dict = json.load(open("words_token_dict.txt")) 
    
    
    news_text_cn_token = [[]]
    
    for j, word in enumerate(remainderWords):
        try:
            # 將詞轉為token之索引
            news_text_cn_token[0].append(token_dict[word])
        except KeyError:
            # 如果詞不在token中，索引為0
            news_text_cn_token[0].append(0)
    
    news_text_cn_token_pad = pad_sequences(news_text_cn_token,
                                           maxlen=145,
                                           padding='pre',
                                           truncating='pre')
    

    result = model.predict(x=news_text_cn_token_pad)
    coef = result[0][0]
    if coef >= 0.5:
        print('是一例正面评价','output=%.2f'%coef)
    else:
        print('是一例负面评价','output=%.2f'%coef)
# Out:
# 20190306 林伯豐讚韓國瑜建議政府降稅拚經濟
# 是一例正面评价 output=0.63
# 20190307 全球離岸風電新建以500GW為目標WFO邀台廠加入
# 是一例负面评价 output=0.50
# 20190308 東元集團徵才300人月薪最高45K
# 是一例负面评价 output=0.40
# 20190311 反核大將提廢核四公投要跟擁核「直球對決」
# 是一例负面评价 output=0.45
# 20190312 ​蔡政府能源政策的全民代價
# 是一例正面评价 output=0.59
# 20190313 首例「死當」環評訴願竟成功福海離岸風電「敗部復活」
# 是一例正面评价 output=0.53
# 20190314 【名采】阮慶岳專欄：看風水
# 是一例负面评价 output=0.38
# 20190318 拱祥生：智慧區域電網來解尖峰負載危機
# 是一例负面评价 output=0.48
# 20190318 智慧區域電網來解尖峰負載危機拱祥生
# 是一例负面评价 output=0.48
# 20190319 張善政看賴清德挑戰前老闆「是我也會出來」
# 是一例正面评价 output=0.70
# 20190320 死當敗部復活首例福海離岸風電通過環評
# 是一例正面评价 output=0.53
# 20190320 選前凍漲選後漲？沈榮津：今年電價沒上漲壓力
# 是一例负面评价 output=0.35
# 20190321 利率連11凍央行宣布重貼現率維持1375
# 是一例负面评价 output=0.46
# 20190321 台灣港勤公司與歐洲NOS合作培訓離岸風電工作船員
# 是一例正面评价 output=0.67
# 20190322 【蘋果頭家】拼命三郎部長沈榮津：對不起家人
# 是一例负面评价 output=0.33
# 20190322 央行砍今年經濟成長首季理監事會利率連11凍
# 是一例负面评价 output=0.32
# 20190322 沈榮津：不是我不用核能大家要核能卻沒人要核廢料
# 是一例正面评价 output=0.51
# 20190322 經濟部長沈榮津擁核拒核廢卻都要我負責
# 是一例正面评价 output=0.62
# 20190326 能源局長林全能升經部常次41上任
# 是一例负面评价 output=0.50
# 20190327 彰化300公頃良田命運仍未知二林精機園區環評打延長賽
# 是一例正面评价 output=0.53
# 20190403 工總投資高雄1598億元許立明：陳菊任內啟動
# 是一例正面评价 output=0.54
# 20190407 沃旭彰化離岸風電計劃耗資6棟101大樓有錢景卡在政治力
# 是一例负面评价 output=0.48
# 20190418 沃旭離岸風電在地化卡關經長：下周三前討論解套方案
# 是一例正面评价 output=0.62
# 20190425 黨內初選見權謀外交官：不甘心台灣就這樣毀掉
# 是一例正面评价 output=0.69
# 20190427 【廢核遊行】不讓「核電復辟」經部：不走回頭路
# 是一例负面评价 output=0.36
# 20190427 【廢核遊行】蔡賴同場未同框賴清德：早上高雄有活動較晚到
# 是一例负面评价 output=0.32
# 20190429 離岸風電機是啥台大研究生用VR告訴你
# 是一例负面评价 output=0.47

# %% [markdown]
# ## Predict Sentiment by Model
