# %% [markdown]
# ## Import libaray

# %%
import requests, json
from bs4 import BeautifulSoup
import datetime
import re
import jieba.analyse
import glob, os
import time
from PIL import Image

# %% [markdown]
# ## Download data from Appledaily News

# %%
SearchString = "離岸風電"

StartDate_Str = '20180101'

EndDate_Str = '20181225'

StartDate = datetime.datetime.strptime(StartDate_Str,'%Y%m%d')
EndDate = datetime.datetime.strptime(EndDate_Str,'%Y%m%d')

SearchPage = 0

# Define desired replacements for non-chinese words
rep = {
        "GW": "兆瓦", 
        "MW": "萬千瓦", 
        "0": "零",
        "1": "一",
        "2": "二",
        "3": "三",
        "4": "四",
        "5": "五",
        "6": "六",
        "7": "七",
        "8": "八",
        "8": "九" 
      }


while (True):
    
    time.sleep(3)

    SearchPage = SearchPage+1
    url = (
           "https://tw.appledaily.com/search/ajaxresult?querystrS={}".format(SearchString) + 
           "&sort=time" +
           "&searchType=all" +
           "&dateStart={}%2F{}%2F{}".format(StartDate.year, StartDate.month, StartDate.day) +
           "&dateEnd=2018%2F12%2F22".format(EndDate.year, EndDate.month, EndDate.day) + 
           "&page={}".format(SearchPage)
          )

    webdata = requests.get(url).text

    reqsjson = json.loads(webdata)


    for content in reqsjson:
        article_title = content['title']
        article_publish_date = content['pubDate']
        article_data = requests.get(content['sharing']['url']).text

        article_data_suop = BeautifulSoup(article_data, 'html.parser')

        article_text = article_data_suop.find('div',class_='ndArticle_margin').p.get_text()


        # use these three lines to do the replacement
        rep = dict((re.escape(k), v) for k, v in rep.items())
        pattern = re.compile("|".join(rep.keys()))
        article_text = pattern.sub(lambda m: rep[re.escape(m.group(0))], article_text)


        article_text = re.sub(r'[^\u4e00-\u9fa5]', " ",article_text) 
        cn_pattern = re.compile(r'[\u4e00-\u9fa5,\u0020]')
        article_cn_text = "".join(cn_pattern.findall(article_text))

    #     en_pattern = re.compile(r'[\u0061-\u007a,\u0020]')
    #     article_en_text = "".join(unen.findall(my_text2.lower()))
    
        if not os.path.exists(SearchString):
            os.makedirs(SearchString)
            
        SaveTitle = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。?、~@#￥%……&*（）]+", "",article_title)
        
        try:
            with open("{0}\{1}_{2}.txt".format(SearchString,article_publish_date,SaveTitle), "w", encoding = 'utf8') as text_file:
                text_file.write(article_cn_text)
        except:
            continue

        print ("{0}_{1}".format(article_publish_date,article_title))

        
    num_article_publish_date = datetime.datetime.strptime(article_publish_date,'%Y%m%d')
    
    if num_article_publish_date < StartDate or webdata == "[]":
        break
        
    print ('done page{}'.format(SearchPage))
    
print ('done all')
# Out:
# 20181217_藍營立委卡再生能源基金　衰到太陽能業者
# 20181215_綠能爆財務困境　牽連太陽能個股全走跌
# 20181213_台加經貿對話　聚焦投保協定與離岸風電
# 20181213_離岸風電融資管道　明年起新增兩大項
# 20181212_台加投保協議　明天可望討論
# 20181212_加拿大首度表態 擬與我談投保協議
# 20181211_【華為公主被捕】時機敏感　加國外長：考慮跟台灣簽投保議
# 20181211_採購風電價格每度要5.8元　藍委呼籲鄭文燦不要圖利廠商
# 20181211_高銘志：離岸風電爭議，漁業署的確強渡關山
# 20181211_十二月十一日各報頭條搶先看
# 20181210_製造業Q3固定資產增購年增24.3%
# 20181210_回應監察院離岸風電檢討報告　經濟部：幫全民省4千億
# 20181209_鋼鐵上游穩中下游苦　明年看美國臉色
# 20181208_打空污牌勝選，更該推動再生能源扎根中台灣
# 20181205_十二月五日財經焦點搶先看
# 20181205_離岸風電太陽能廠 嗆撤資 政府補助大砍超過1成
# 20181204_【撂狠話】離岸風電補助遭砍逾1成　4外商大廠「將撤資」
# 20181204_發展綠能需龐大資金　專家：銀行可借機發展專案融資
# 20181204_離岸風電4大外商嗆撤資　經濟部：調整不能隨口說說
# 20181203_躉購電價大調降　太陽能業者跳腳明開記者會回應
# done page1
# 20181201_媒體追問吳音寧去向　蔡英文：我現在不是黨主席了
# 20181201_GDP今明年都下修 主計總處估本季經濟成長勉強保2
# 20181130_關注離岸風電　丹麥外交部司長級官員首度來台
# 20181130_終結連3季上修！主計處下調今年GDP成長預測至2.66%
# 20181130_開發商齊跳腳！離岸風電躉購費率明年大降12.71%
# 20181130_十一月三十日各報頭條搶先看
# 20181129_搭台商回流順風車，政府可以先做這些事
# 20181129_地震測報太慢被譙怕　氣象局要花12.7億靠這招翻身
# 20181129_明年離岸風電躉購費率擬調降　外商可能「不玩了」
# 20181129_「新經濟移民法」拍板！　開放外國中階技術人力補缺口
# 20181128_「非核家園政策沒有轉彎」　原能會主委：盼核二核三如期除役
# 20181127_行政院：能源政策非髮夾彎　公投是刪掉非核家園截止日期
# 20181127_經濟部長：公投結果未影響綠能　將拜會新任地方首長
# 20181127_「以核養綠」過關 風電概念股遇亂流
# 20181126_【賴清德談話全文】接受總統慰留　留下來繼續努力
# 20181126_【綠地變藍天】台股選後首日漲近百點　韓流概念股氣勢旺
# 20181126_以核養綠公投過關　風電概念股驚嚇皮皮剉
# 20181126_全球首開求穩定　中鋼Q1盤價終止連五漲
# 20181122_離岸風電外商抱怨國產化太貴　沈榮津：會找大家來談
# 20181116_wpd達德能源來函澄清「風力發電掛零」一文
# done page2
# 20181114_沃旭、興達海基簽水下基礎合約　力拚離岸風電在地化
# 20181114_離岸風電拚本土化　CIP評估台灣選舉與公投不影響投資
# 20181114_沈榮津：躉購電價費率月底或下月初預告
# 20181113_綠能外商設彰化辦公室　彰化青年回流任經理
# 20181113_沃旭今與大葉大學簽學徒制　明年起培育離岸風電人才
# 20181113_2025廢核　台大醫憂：台灣將有6個恐怖的世界第一
# 20181112_全球最大離岸風電沃旭　與中鋼簽全球最大單
# 20181108_風電葉片產業鏈聯盟成立　明年底葉片製造廠完工
# 20181107_台中港設亞洲最大85米風機葉片廠　30億打造「風電台積電」
# 20181107_天力公司風電在地化最佳典範  千億風電葉片產業鏈聯盟成立
# 20181105_經濟部歐洲招商訪歐8大企業　英商將來台設iDream中心
# 20181101_世界能源需求25年後成長1倍
# 20181031_缺地荒　經濟部2022年前要釋出1470公頃
# 20181024_台船搶離岸風電商機　辦Marine-Team廠商大會
# 20181019_中經院上修今年GDP成長率至2.61%　明年可望「保2」
# 20181017_【蘋中人】從零開始 詹順貴
# 20181014_【盤點十大公共工程】空污不降反升　公路總局最嚴重
# 20181010_【國慶演說全文】蔡英文向中國喊話　「不要當衝突來源」
# 20181008_全球招商誇大金額是騙局?　經部：誤會
# 20181008_詹順貴3千字辭職信全文　「離修法目標越來越遠、有愧職守」
# done page3
# 20181006_蔡英文參加環保志工活動　強調消滅老車是假消息
# 20181004_回應工總林明儒《七大理由，工總支持深澳採燃煤》一文
# 20181003_​西門子歌美颯簽訂首批國產化合約　上緯金豐獲青睞
# 20181003_風機大廠西門子歌美颯　今首度與台2家供應鏈廠商簽約
# 20181003_​王明鉅：1200億蓋離岸風電，只能創造2萬個職缺？
# 20181003_中鋼組國家隊搶攻離岸風電商機　Wind-Team供應商大會今登場
# 20181003_世紀鋼CIP簽約 165億拼風電
# 20181002_離岸風場首筆大單　世紀鋼與CIP簽約
# 20181002_「太陽能」淪台灣另一個夕陽「慘」業？
# 20181001_​王明鉅：領先全世界廢核，真的愛台灣嗎？
# 20180927_綠委爆侯友宜影片違規使用　侯辦：抹黑掩蓋不了汙染
# 20180927_韓國瑜宣稱乳癌治療200美元　民進黨批：沒水準兼不衛生
# 20180926_遭質疑拋棄綠電　台電：已加強電網讓再生能源順利併網
# 20180925_歐盟與15會員國駐台代表處：呼籲展開行動，落實巴黎氣候協定
# 20180922_日本招商成果豐　加強推動航太、離岸風電
# 20180919_蔡英文：台灣能源轉型充滿信心　同時也不會缺電
# 20180918_​四合一再生能源大展明登場　台灣太陽能裝置將今年將達1GW
# 20180918_赴新屋了解離岸風電　陳學聖：錯誤政策肥了財團卻害了百姓
# 20180918_【台股盤中】蘋概股股價疲軟　指數反彈須帶量
# 20180913_彰濱工業區陸上變電站　CIP與本土廠商簽工程合約
# done page4
# 20180912_陳立誠：深澳電廠空污致死平議
# 20180912_沃旭今與台灣供應商穩晉簽約　投資全新的海纜鋪設船
# 20180912_打臉賴清德！環評委員技術性杯葛流會　中油三接站案2周後再戰
# 20180912_【台股盤中】開高走低   生技傳產股成資金避風港
# 20180910_來勢洶洶 恐有雙颱撲台 山竹轉中颱 基隆冒黃泥瀑布
# 20180909_離岸風電工作船進水傾斜　海巡大浪救出18人
# 20180908_這個科系曾停招14年　去年、今年全都滿招
# 20180905_蕭士俊：超颱癱瘓關西機場    台灣海岸工程應考慮極端氣候
# 20180905_​想要「非核家園」　必須先「以核養綠」
# 20180830_一位鹿港居民的心聲：我曾參與反杜邦，我期待離岸風電到彰化
# 20180830_澳洲駐台代表：澳洲─台灣現在與未來的能源夥伴
# 20180830_永續價值領航者　國泰金6度贏天下企業公民獎
# 20180830_【正方說法】深澳電廠對北台灣無比重要（陳立誠）
# 20180830_【深澳電廠要蓋嗎】陳立誠：深澳電廠對北台灣無比重要
# 20180828_離岸風電供應鏈在地化　西門子估創造2萬就業機會
# 20180822_力拼離岸風電供應鏈在地化　沃旭將再簽10項新合約
# 20180820_建新國際下月中掛牌上市　樂觀下半年業績反彈
# 20180811_中彰投拼輔選　蔡英文：國民黨不唱衰台灣很難嗎
# 20180810_彰濱、台南地面型太陽光電　台電拚2年內完工
# 20180810_台大醫：2025年台灣將難逃缺電、限電、停電
# done page5
# 20180810_離岸風電「愚公」嘆：台灣關注低
# 20180810_缺電 半導體不敢設廠 商界憂：備轉容量應有15％ 台灣只到6％
# 20180809_【電力不足1】缺電逼走企業經濟崩！　商界怒譙：備轉容量率嚴重不足
# 20180809_太陽能、風電廠迎能源轉型　業者嘆「離岸風電關注低」
# 20180806_外媒：「核能鬼城」揭露台灣電力風險
# 20180803_蔡英文批國民黨：天氣熱台灣沒缺電　謠言不攻自破
# 20180802_馬江主張「以核養綠」　蔡英文：落後世界潮流的說法
# 20180730_海外招商鎖定美日歐　美國首發團昨出發
# 20180730_挽救台灣之光 搶攻軍艦風電
# 20180730_台船鄭文隆 不能敗的壓力
# 20180729_國艦國造台船178億得標　徵才將破200人
# 20180727_國產風場運輸船啟航　魏明谷：「比歐洲的先進」
# 20180724_嘉里大榮跨足海上風電　成立保時嘉里潔能
# 20180724_氣象局與能源局公布　台灣最佳風、太陽光電開發區
# 20180724_離岸風電商機大 人力需求爆增
# 20180723_離岸風場鑽探船啟航　不下錨降低對附近漁船影響
# 20180721_尖峰用電飆今年第10高 經長仍掛保證「沒意外就不缺電」
# 20180720_​非核家園仰賴風電　台大醫：天天擔心815大停電重演
# 20180720_經長：只要電廠沒發生意外　今年不缺電
# 20180719_台船董座：最艱苦的一年已經過去　下半年優於上半年
# done page6
# 20180718_離岸風電挨批太貴　賴清德：買鞋第一雙原價、第二雙五折
# 20180718_「禁採砂石一定得罪人」　蔡英文：對魏明谷連任有信心
# 20180718_為台灣離岸風電工程量身打造　台船140公尺大型駁船開工
# 20180715_【更新】國民黨批蔡英文　氣急敗壞敗象已現
# 20180712_【閣員三大難題】快速掌握精準回應　Kolas獨當一面挑戰政院發言人
# 20180711_推動台灣離岸風能教育　台丹首度產學交流
# 20180709_彰縣校園種電進帳破億　多校獲逾百萬回饋金
# 20180709_學者籲接收站改台北港　中油：時程來不及
# 20180707_莊秉潔：觀塘站失敗 是能源轉型好的開始
# 20180705_與高屏綠委餐敘　蔡英文盼立委多上節目說明政策
# 20180705_離岸風電價差大　監委憂國庫失血要查
# 20180705_環保聯盟會長：核四燃料棒開始外運 關鍵的一步
# 20180705_2025年離岸風電總投資9625億元　經濟部：創造2萬個就業機會
# 20180704_離岸風電招摽價差大　藍委赴監察院告發經濟部
# 20180702_風電競標價相差9000多億元？全民買單
# 20180701_被高估的福島核災處理費與核電成本
# 20180629_【有片】離岸風電競標藍委告沈榮津圖利　經濟部：請提出證據
# 20180629_國民黨團向檢調告發　離岸風電招標價差離譜
# 20180628_​高銘志：離岸風電遴選疑涉公務員洩密
# 20180628_台船股東會　董座：力拚明年轉虧為盈
# done page7
# 20180628_「看天吃飯」綠電不穩
# 20180627_高銘志：官員上節目 關於離岸風電競標破盤價澄清了什麼
# 20180627_經濟部新聞稿連3發　強調跳電都是外力因素
# 20180627_【搶救競爭力-專訪】馬英九拋「以核減碳養綠」　呼籲放棄2025非核家園
# 20180627_【搶救競爭力-缺電篇】綠電不穩、 燃氣難建　非核家園的難關
# 20180625_【K律師論點】離岸風電是啥　可以吃嗎？
# 20180622_離岸風電競標今出爐　4風場、2開發商開出破盤價
# 20180622_【更新】離岸電廠競標　海龍每度2.2245元得標低於預期
# 20180620_攜手台船建教合作　聖約翰讓學生贏在起跑點
# 20180619_離岸風電競價收件今截止　12座風場提申請
# 20180618_彰化視察遇大風雨　賴揆：風力發電應該不錯
# 20180615_東元電機發現金0.86元　未來智能產品成長2成
# 20180604_3年跳電近5萬次　經長撂話要台電負責
# 20180601_國發會主委陳美伶赴歐　正式表達申請GDPR意願
# 20180531_跳電問題被女藍委砲轟　經濟部長罕見動怒
# 20180523_高院法官到澎湖交流　挨批用公帑爽玩
# 20180523_【八方聊天室】蘇煥智罵：民進黨變一言堂　蔡英文不懂傾聽
# 20180522_離岸風電競標　上緯要全力備標
# 20180520_【彰化選情】魏明谷主攻政績牌　王惠美緊咬端牛肉
# 20180519_拼轉型　台泥、亞泥如何水泥綠能兩邊賺
# done page8
# 20180518_Wind-team聯盟倍增至38家　進入實際技術培植
# 20180517_離岸風電聯貸扯上政治　立委與行庫董座針鋒相對
# 20180517_離岸風電融資風險高 　公股行庫不敢辦聯貸
# 20180515_東元與三菱重工簽MOU　承製9.5MW風機
# 20180514_白海豚僅存70隻列瀕危　生態衝擊1年死2隻
# 20180514_颱風會造成離岸風電損壞　經濟部：不實指控
# 20180512_綠能產業論壇　23日移師台南
# 20180509_丹麥能源集團　將台、美並列離岸風電重點
# 20180509_台菲爐石大戰　中鋼：菲國沒毀約、不打國際仲裁
# 20180508_離岸風電發展 會不會自己打自己（李界木）
# 20180508_李界木：離岸風電發展 會不會自己打自己
# 20180506_等嘸「台灣價值」答案卷 綠分手柯文哲
# 20180505_小英開支票：年輕人將在離岸風電開創人生
# 20180505_參觀離岸風機　小英笑問記者：會不會暈船？
# 20180505_吳茂昆談「拔管」　籲用正確語詞
# 20180504_台灣港務公司擴大招考　203人起薪3萬至8萬
# 20180504_利空未出盡　上緯控股連3日跌停
# 20180503_第二屆海事展九月聚焦高雄　規模再擴大
# 20180503_離岸風電遴選落榜利空　上緯開盤再鎖跌停
# done page9
# 20180502_離岸風電落榜拖累股價　上緯自結3月每股虧0.07元
# 20180502_離岸風力躉售價偏高　經長：影響電價每度約0.27元
# 20180502_油價緩漲機制　經長：是否有凍漲機制討論中
# 20180502_沈榮津滿意離岸風電遴選結果　影響電價僅0.27元
# 20180502_台多斷交　經濟部長：初評對台商影響不大
# 20180502_離岸風電遴選不如預期　拖累上緯跌停
# 20180502_油價3周狂漲1.5元　經長：會設價格級距緩漲
# 20180502_離岸風電遴選外商大勝　概念股全倒
# 20180502_比利時商攜日立　獲台電風場發電機組21支訂單
# 20180501_奪台電訂單　日立：以台灣為進攻亞洲起點
# 20180501_7業者勝出 離岸風電 中鋼台電大黑馬
# 20180430_離岸風電遴選　外商達德能源WPD大贏家
# 20180430_離岸風場遴選10案過關　亞泥、力麗落榜
# 20180430_離岸風電遴選　亞泥力麗落選、中鋼台電獲選
# 20180430_離岸風電遴選 今公布得標名單
# 20180429_離岸風電兆元產業將啟動　每年用鋼20萬噸
# 20180429_離岸風電遴選明出爐！本土業者有話要說...
# 20180427_離岸風電概念股又多一家！今與沃旭簽MOU
# 20180427_能源選項不是只有非核即煤（蔡卉荀、李根政）
# 20180427_蔡卉荀、李根政：能源選項不是只有非核即煤
# done page10
# 20180426_海洋風電第二階段　沃旭擬加碼投資
# 20180426_保守的能源政策正是讓台灣落後國際的原因
# 20180425_業者心聲：有政府支持，離岸風電成本才能下降
# 20180424_沃旭攜台廠　下月展開大彰化風電海床調查
# 20180424_遴選將出爐　海龍風電搶下首張彰縣府同意書
# 20180423_深澳電廠爭議　經部長：穩定供電不能放棄燃煤
# 20180423_風力發電會出現下一個宇昌案嗎？
# 20180422_攜手華城　上緯海洋風電升變壓站工程擴充
# 20180422_世界地球日！　上緯攜手國泰金淨灘
# 20180420_離岸風電首場遴選今展開　4月底公布結果
# 20180415_盼消滅蚊子館　興達港離岸風電基礎廠房動工
# 20180415_中鋼風電水下基礎廠房今動土　拚明年底完工
# 20180415_市場風險逐漸淡化　布局台股時機浮現
# 20180415_傳產搏翻身　這家紡織廠導入智慧機械
# 20180413_2倍價格買離岸風電　藍委痛罵政府當冤大頭
# 20180412_離岸風電高價簽約20年　立委憂「民營電廠翻版」
# 20180412_離岸風電遴選　技術、財務能力各佔60%、40%
# 20180409_台股盤中～連假收心開盤　本周先看股王法說
# 20180408_轉型2次不見繁榮 興達港砸77億沒船停泊
# 20180408_【咩姊台語】數度活化失敗　蚊子館淪錢坑
# done page11
# 20180406_能源局離岸風電遴選收件　最快4月底有結果
# 20180406_​Formosa 1離岸風力發電擴建案　西門子歌美颯得標
# 20180403_高銘志：台電示範風場計畫爭議真已釐清？
# 20180331_​陽光能源進行重整　買回錦州茂迪17.8％股權
# 20180331_達德搶離岸風電 攜手中鼎等廠
# 20180330_​高銘志：廠商帶錢來？全民協尋台電消失的250億！
# 20180329_首間台灣風能訓練公司　最快明年初招生
# 20180328_已羨慕！中鋼4月起調薪3.5%　調幅近7年新高
# 20180326_違法烏雲罩頂的離岸風電競標遴選（高銘志）
# 20180326_高銘志：違法烏雲罩頂的離岸風電競標遴選
# 20180322_推動離岸風電　行政院：2025年台灣有能力做開發商
# 20180320_亞泥攜手CIP 拼離岸風電
# 20180317_推離岸風電 沃旭攜手大學培育人才
# 20180316_彰化離岸風電首桶金進帳　大學將開課育才
# 20180316_沃旭與世紀鋼簽約　採購9000萬元管架式水下基礎
# 20180315_電價喊漲 經長鬆口「以價制量」
# 20180314_王文淵憂綠能造成電價漲？沈榮津這樣回應
# 20180312_環保聯盟副會長：反核遊行人數銳減的另一層意含
# 20180311_蔡英文：2025非核家園已入法　能源轉型是進行式
# done page12
# 20180309_逆風入美國市場　一銀擬設美國德州分行
# 20180309_國銀第1家 一銀赴美設德州分行
# 20180307_沃旭4風場投資3800億　母公司擔保融資、擬發綠色債
# 20180304_CIP下半年成立維護運轉基地　7產業將受惠
# 20180301_綠能風電彰縣招商　50餘家企業興致勃勃
# 20180301_離岸風電將由航港局劃設航道　違者最高罰50萬元
# 20180226_亞泥拼離岸風電　獲銀行團600億融資支持
# 20180222_中鋼面臨7千人退休潮　董座團拜盼做好傳承
# 20180222_六大行庫　今年徵才超過2200人
# 20180213_台電離岸風電完成招標　2020年可供9萬家戶一年用電
# 20180213_​西門子與永冠能源簽約　發展離岸風力發電
# 20180209_福海彰化離岸風力發電計畫　環署今環評大會未通過
# 20180208_立院副院長蔡其昌：持續推動政治中心移台中
# 20180208_全球風電龍頭 彰化建大型儲能設施
# 20180207_沃旭加碼彰化　打造首個百萬瓦儲能設施
# 20180207_世紀鋼自結去年12月EPS 0.06元　年減4成
# 20180131_兩本土財團離岸風電環評案　遠東過關、上緯要補正
# 20180127_台船攜手丹麥風電大廠　力攻海上變電站商機
# 20180123_桃園離岸發電有譜　廠商簽合作2020發電併網
# 20180122_離岸風電迎外商　龔明鑫：讓台灣產業向上升級
# done page13
# 20180121_環評阻產業發展？環保署反駁
# 20180118_賴揆指示政委督導綠能產業計畫　每月整體報表
# 20180117_台灣離岸風電5.5G　荷蘭願協助培訓海事工程人才
# 20180117_離岸風電兩案闖關　台電過關、桃新失敗
# 20180117_近岸離岸風電案今闖環評　環團居民喊否決
# 20180116_離岸風電遴選 避免贏者全拿
# 20180115_經部公布離岸風電遴選辦法　2025產值拚1218億元
# 20180115_一月十五日各報頭條搶先報
# 20180107_用地難取得 行政效率差 5+2產業淪空談
# 20180105_響應小英喊加薪　港務公司：基層加薪最高5.62%
# 20180104_能源轉型具風險？經部：確保穩定供電前提下進行
# 20180104_​上緯董座叫屈　民間與政府對離岸風電關注低
# 20180104_新年新希望　經長沈榮津許了這3個願望
# 20180103_「示範」風機給補考還是死當　福海離岸風電不能開發
# 20180102_台中港離岸風電產業園區　5A碼頭明年完工
# done page14
# done all

# %%
# os.chdir(".")
words_list = []
os.chdir("離岸風電")
for file in glob.glob("*.txt"):
    
    with open( file, "rb") as f:
        for line in f:
            tags = jieba.analyse.extract_tags(line, topK=10, withWeight=True)
            for tag, weight in tags:
                words_list.append(tag)
                
print ('done')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\BENLIN~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.813 seconds.
# Prefix dict has been built succesfully.
# done

# %%
from collections import Counter

counts = Counter(words_list)
print(counts)
# Out:
# Counter({'離岸': 124, '台灣': 99, '風電': 64, '彰化': 32, '能源': 31, '風場': 27, '報導': 27, '發展': 27, '經濟部': 25, '零零': 25, '產業': 24, '遴選': 24, '投資': 22, '風力': 21, '發電': 21, '經濟': 19, '沈榮津': 17, '千瓦': 17, '基礎': 17, '轉型': 16, '二零二': 16, '推動': 16, '沃旭': 16, '兆瓦': 15, '風機': 15, '綠能': 15, '太陽能': 15, '開發': 14, '電廠': 14, '中鋼': 13, '價格': 13, '非核': 12, '二零一': 12, '階段': 11, '市場': 11, '容量': 11, '立委': 11, '電力': 11, '上緯': 10, '台電': 10, '影響': 10, '我們': 10, '英文': 10, '再生能源': 10, '規劃': 9, '相關': 9, '台船': 9, '未來': 9, '競價': 9, '廠商': 9, '公投': 9, '企業': 9, '技術': 8, '環境': 8, '審查': 8, '億元': 8, '水下': 8, '國民黨': 8, '業者': 8, '成長': 8, '環評': 7, '穩定': 7, '問題': 7, '民進': 7, '江俞庭': 7, '目標': 7, '家園': 7, '政府': 7, '每度': 7, '天然': 7, '完工': 6, '國際': 6, '合約': 6, '行政院': 6, '深澳': 6, '地化': 6, '競標': 6, '結果': 6, '海事': 6, '總統': 6, '選舉': 6, '缺電': 6, '台中港': 5, '專案': 5, '供電': 5, '進行': 5, '預計': 5, '透過': 5, '建置': 5, '世紀': 5, '集團': 5, '西門子': 5, '歌美颯': 5, '電價': 5, '計畫': 5, '賴清德': 5, '作業': 5, '興達': 5, '機會': 5, '九元': 5, '簽署': 5, '調降': 5, '一零': 4, '外商': 4, '銀行': 4, '綜合': 4, '至於': 4, '變電站': 4, '設備': 4, '丹麥': 4, '建設': 4, '亞泥': 4, '超過': 4, '美國': 4, '機組': 4, '社會': 4, '核電廠': 4, '核電': 4, '時間': 4, '積極': 4, '國內': 4, '風險': 4, '強調': 4, '減少': 4, '燃煤': 4, '裝置': 4, '預估': 4, '中油': 4, '預期': 4, '媒體': 4, '工程': 4, '已經': 4, '台北': 4, '搶救': 4, '競爭力': 4, '鄭文隆': 4, '不過': 4, '財經': 4, '專業': 4, '貿易': 4, '購費率': 4, '蔡朝陽': 3, '港務': 3, '新聞': 3, '申請': 3, '智慧': 3, '環保署': 3, '龔明鑫': 3, '設置': 3, '通過': 3, '儲能': 3, '夥伴': 3, '執行': 3, '設施': 3, '規定': 3, '第一': 3, '獲利': 3, '廢核': 3, '審議': 3, '漲幅': 3, '五零': 3, '採購': 3, '日立': 3, '中國': 3, '部長': 3, '竹南': 3, '收購': 3, '招標': 3, '創造': 3, '工業': 3, '台股': 3, '海洋': 3, '歐盟': 3, '我國': 3, '澳電廠': 3, '本土': 3, '本土化': 3, '評估': 3, '經驗': 3, '油價': 3, '報告': 3, '參加': 3, '虧損': 3, '營收': 3, '高雄': 3, '失敗': 3, '融資': 3, '彰濱': 3, '魏明谷': 3, '課程': 3, '一個': 3, '缺電篇': 3, '委員': 3, '時程': 3, '國造': 3, '今年': 3, '用電': 3, '這麼': 3, '除役': 3, '雙方': 3, '國家': 3, '補助': 3, '林巧雁': 3, '總處': 3, '預測': 3, '天力': 3, '海基': 3, '核養': 3, '費率': 3, '協議': 3, '碼頭': 2, '決議': 2, '擁有': 2, '升級': 2, '加薪': 2, '時報': 2, '基層': 2, '調整': 2, '同仁': 2, '公司': 2, '市長': 2, '重點': 2, '新北市': 2, '國產化': 2, '辦法': 2, '舉辦': 2, '辦事處': 2, '白海豚': 2, '創新': 2, '投資金額': 2, '桃園': 2, '領域': 2, '海能': 2, '竹風': 2, '推估': 2, '財報': 2, '百萬瓦': 2, '等級': 2, '計劃': 2, '漁業': 2, '第一期': 2, '二四': 2, '總經理': 2, '起薪': 2, '會議': 2, '九零': 2, '分行': 2, '德州': 2, '團體': 2, '台幣': 2, '全力': 2, '遴競': 2, '命令': 2, '關鍵': 2, '分配': 2, '董事': 2, '風能': 2, '金額': 2, '什麼': 2, '收件': 2, '簽約': 2, '機場': 2, '漁港': 2, '遠洋泊區': 2, '專區': 2, '興建': 2, '開盤': 2, '二零年': 2, '必須': 2, '興達港': 2, '機械': 2, '生產': 2, '指數': 2, '五年': 2, '三七': 2, '發電量': 2, '調查': 2, '縣府': 2, '同意': 2, '外國': 2, '標準': 2, '入選': 2, '芳苑': 2, '台商': 2, '設計': 2, '購價格': 2, '機制': 2, '緩漲': 2, '調漲': 2, '購電價': 2, '虧零': 2, '客戶': 2, '獲得': 2, '高達': 2, '萬元': 2, '五九': 2, '年增': 2, '資訊': 2, '沒有': 2, '台大': 2, '永續': 2, '議題': 2, '協會': 2, '侵襲': 2, '東元': 2, '電機': 2, '因為': 2, '張兆順': 2, '陸域': 2, '參選': 2, '二五': 2, '記者': 2, '檢討': 2, '過去': 2, '持續': 2, '學生': 2, '造船': 2, '聯盟': 2, '數字': 2, '官員': 2, '過程': 2, '政策': 2, '日本': 2, '成本': 2, '接收站': 2, '北部': 2, '大潭': 2, '實習': 2, '回應': 2, '施政': 2, '特別': 2, '駁船': 2, '污染': 2, '王明': 2, '停電': 2, '氣象局': 2, '太陽光': 2, '地熱': 2, '設廠': 2, '簽訂': 2, '風電產業': 2, '氣候': 2, '電子': 2, '大會': 2, '海纜': 2, '電網': 2, '二三': 2, '影片': 2, '侯友宜': 2, '醫療': 2, '全球': 2, '塔架': 2, '金豐': 2, '空污': 2, '明年': 2, '民間': 2, '合作': 2, '機葉': 2, '人才': 2, '購電': 2, '零九': 2, '延役': 2, '蘋果': 2, '主計': 2, '加拿大': 2, '加國': 2, '方慧蘭': 2, '善意': 2, '台加': 2, '公尺': 1, '承載力': 1, '零六': 1, '第一季': 1, '組裝': 1, '開工': 1, '小組': 1, '示範': 1, '關注度': 1, '促進': 1, '關注': 1, '經部': 1, '保供': 1, '減排': 1, '可維持': 1, '人員': 1, '調薪': 1, '吳宏謀': 1, '二產業': 1, '忡忡': 1, '投資動': 1, '作為': 1, '驅動': 1, '夜市': 1, '遷籍': 1, '陸客': 1, '二零二一': 1, '工業局': 1, '項目': 1, '一二一': 1, '荷蘭': 1, '兩案': 1, '桃新': 1, '風電案': 1, '認定': 1, '不應': 1, '達成': 1, '胡勝正': 1, '能量': 1, '達德': 1, '觀音': 1, '海上': 1, '三方': 1, '飛行': 1, '鳥類': 1, '自結': 1, '稅後純益': 1, '三萬元': 1, '飆漲': 1, '二月': 1, '去年': 1, '加碼': 1, '首個': 1, '風電龍頭': 1, '商沃旭': 1, '將加碼': 1, '蔡其昌': 1, '以二零年': 1, '軌道': 1, '台中市': 1, '現階段': 1, ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

my_color_fig = np.array(Image.open("aaa.jpg"))
image_colors = ImageColorGenerator(my_color_fig)

text = ','.join(words_list)

# 設定停用字(排除常用詞、無法代表特殊意義的字詞)
stopwords = {}.fromkeys(["沒有","一個","什麼","那個","二零一","二零二","零零"])

# 產生文字雲
wc = WordCloud(font_path="NotoSansCJKtc-Bold.otf", #設置字體
               background_color="white", #背景顏色
               max_words = 250 ,        #文字雲顯示最大詞數
               width=1600,
               height=800,
               stopwords=stopwords)      #停用字詞

wc.generate(text)

# 視覺化呈現
plt.figure(figsize=(20,10), dpi = 200)
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.savefig('wordcloud.png', bbox_inches='tight', dpi = 200)
plt.show()
# wc.to_file("first_review.png")
